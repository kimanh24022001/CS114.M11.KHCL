# %% [markdown]
# # **Rút gọn phân số**
# Viết chương trình rút gọn phân số.
#
# INPUT
#
# Dòng đầu tiên là một số nguyên
# n
#
# (
# 1
# ≤
# n
# ≤
# 100
# )
#  — Số lượng phân số cần rút gọn
#
# n
#  dòng tiếp theo là hai số nguyên
# a
# ,
# b
# (
# a
# ,
# b
# ≥
# 1
# )
#  —
# a
# ,
# b
#  lần lượt là tử số và mẫu số.
#
#  OUTPUT
#
# Ứng với
# n
#  dòng, in ra theo thứ tự tử số và mẫu số (cách nhau một khoảng trắng) sau khi rút gọn; mẫu số chỉ được in khi lớn hơn 1.
#
# Ví dụ:
#
# INPUT:
#
# 5
#
# 6 8
#
# 3 7
#
# 5 10
#
# 10 5
#
# 25 100
#
# OUTPUT
#
# 3 4
#
# 3 7
#
# 1 2
#
# 2
#
# 1 4
#
#
# **Python code**

# %%
from fractions import Fraction
n=int(input())
def ucln(a,b):
	a=abs(a)
	b=abs(b)
	if a==0 or b==0:
		return a+b
	while a!=b:
		if a>b:
			a=a-b
		if b>a:
			b=b-a
	return a
    
for i in range(0,n):
	tu,mau=map(int, input().split())
	if Fraction(Fraction(tu,mau)).denominator==1:
			print(Fraction(Fraction(tu,mau)).numerator)
	else:
		print(Fraction(Fraction(tu,mau)).numerator,Fraction(Fraction(tu,mau)).denominator)
	# your code goes here
